# %% [markdown]
# # reGrainable - <font color='orange'>Slice parameters dataframe</font>
#
# Miguel Moreno, NBI-UCPH, 2023

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Each dictionary represents a row in the final DataFrame.
# For '_2' entries, px_right is calculated based on the width of the corresponding '_1' entry.

slicing_data = [
    # nmx3642b
    {
        "name": "nmx3642b_1",
        "px_left": 59023,
        "px_top": 888,
        "px_bottom": 6814,
        "px_right": 117782,
    },
    {
        "name": "nmx3642b_2",
        "px_left": 58998,
        "px_top": 1784,
        "px_bottom": 5950,
        "px_right": (117782 - 59023) + 58998,
    },  # Calculated: width_1 + px2_left
    # nmx3642c
    {
        "name": "nmx3642c_1",
        "px_left": 8311,
        "px_top": 1200,
        "px_bottom": 6406,
        "px_right": 59020,
    },
    {
        "name": "nmx3642c_2",
        "px_left": 8286,
        "px_top": 1385,
        "px_bottom": 6027,
        "px_right": (59020 - 8311) + 8286,
    },  # Calculated
    # nmx3643b
    {
        "name": "nmx3643b_1",
        "px_left": 10045,
        "px_top": 1430,
        "px_bottom": 6826,
        "px_right": 118645,
    },
    {
        "name": "nmx3643b_2",
        "px_left": 10021,
        "px_top": 1810,
        "px_bottom": 5780,
        "px_right": (118645 - 10045) + 10021,
    },  # Calculated
    # nmx3644b
    {
        "name": "nmx3644b_1",
        "px_left": 8371,
        "px_top": 690,
        "px_bottom": 6266,
        "px_right": 118594,
    },
    {
        "name": "nmx3644b_2",
        "px_left": 8347,
        "px_top": 1251,
        "px_bottom": 6120,
        "px_right": (118594 - 8371) + 8347,
    },  # Calculated
    # nmx3645c (only one part)
    {
        "name": "nmx3645c_1",
        "px_left": 10630,
        "px_top": 1000,
        "px_bottom": 8192,
        "px_right": 118790,
    },
    # nmx3646b
    {
        "name": "nmx3646b_1",
        "px_left": 8785,
        "px_top": 872,
        "px_bottom": 6592,
        "px_right": 119015,
    },
    {
        "name": "nmx3646b_2",
        "px_left": 8760,
        "px_top": 1573,
        "px_bottom": 5753,
        "px_right": (119015 - 8785) + 8760,
    },  # Calculated
    # nmx3647b
    {
        "name": "nmx3647b_1",
        "px_left": 10060,
        "px_top": 1040,
        "px_bottom": 5946,
        "px_right": 118552,
    },
    {
        "name": "nmx3647b_2",
        "px_left": 10036,
        "px_top": 945,
        "px_bottom": 6060,
        "px_right": (118552 - 10060) + 10036,
    },  # Calculated
    # nmx3649c
    {
        "name": "nmx3649c_1",
        "px_left": 9566,
        "px_top": 1400,
        "px_bottom": 5924,
        "px_right": 118820,
    },
    {
        "name": "nmx3649c_2",
        "px_left": 9542,
        "px_top": 908,
        "px_bottom": 5070,
        "px_right": (118820 - 9566) + 9542,
    },  # Calculated
    # nmx3650c
    {
        "name": "nmx3650c_1",
        "px_left": 7944,
        "px_top": 500,
        "px_bottom": 6586,
        "px_right": 117802,
    },
    {
        "name": "nmx3650c_2",
        "px_left": 7923,
        "px_top": 1575,
        "px_bottom": 4966,
        "px_right": (117802 - 7944) + 7923,
    },  # Calculated
    # nmx3651b
    {
        "name": "nmx3651b_1",
        "px_left": 10283,
        "px_top": 1560,
        "px_bottom": 5915,
        "px_right": 118600,
    },
    {
        "name": "nmx3651b_2",
        "px_left": 10259,
        "px_top": 896,
        "px_bottom": 5480,
        "px_right": (118600 - 10283) + 10259,
    },  # Calculated
    # nmx3652b
    {
        "name": "nmx3652b_1",
        "px_left": 8107,
        "px_top": 880,
        "px_bottom": 5968,
        "px_right": 118565,
    },
    {
        "name": "nmx3652b_2",
        "px_left": 8084,
        "px_top": 949,
        "px_bottom": 3362,
        "px_right": (118565 - 8107) + 8084,
    },  # Calculated
    # nmx3653b
    {
        "name": "nmx3653b_1",
        "px_left": 9328,
        "px_top": 760,
        "px_bottom": 5078,
        "px_right": 117951,
    },
    {
        "name": "nmx3653b_2",
        "px_left": 9304,
        "px_top": 59,
        "px_bottom": 3790,
        "px_right": (117951 - 9328) + 9304,
    },  # Calculated
    # nmx3655c
    {
        "name": "nmx3655c_1",
        "px_left": 9397,
        "px_top": 440,
        "px_bottom": 5849,
        "px_right": 118890,
    },
    {
        "name": "nmx3655c_2",
        "px_left": 9379,
        "px_top": 840,
        "px_bottom": 4182,
        "px_right": (118890 - 9397) + 9379,
    },  # Calculated
    # nmx3656c
    {
        "name": "nmx3656c_1",
        "px_left": 8095,
        "px_top": 557,
        "px_bottom": 6145,
        "px_right": 118151,
    },
    {
        "name": "nmx3656c_2",
        "px_left": 8073,
        "px_top": 1121,
        "px_bottom": 5467,
        "px_right": (118151 - 8095) + 8073,
    },  # Calculated
    # nmx3657b
    {
        "name": "nmx3657b_1",
        "px_left": 9154,
        "px_top": 630,
        "px_bottom": 5955,
        "px_right": 118705,
    },
    {
        "name": "nmx3657b_2",
        "px_left": 9132,
        "px_top": 949,
        "px_bottom": 5950,
        "px_right": (118705 - 9154) + 9132,
    },  # Calculated
    # nmx3658b
    {
        "name": "nmx3658b_1",
        "px_left": 4903,
        "px_top": 700,
        "px_bottom": 5188,
        "px_right": 114776,
    },
    {
        "name": "nmx3658b_2",
        "px_left": 4881,
        "px_top": 180,
        "px_bottom": 4900,
        "px_right": (114776 - 4903) + 4881,
    },  # Calculated
    # nmx3659b
    {
        "name": "nmx3659b_1",
        "px_left": 8618,
        "px_top": 0,
        "px_bottom": 5465,
        "px_right": 118330,
    },
    {
        "name": "nmx3659b_2",
        "px_left": 8594,
        "px_top": 457,
        "px_bottom": 5060,
        "px_right": (118330 - 8618) + 8594,
    },  # Calculated
    # nmx3661b (only one part)
    {
        "name": "nmx3661b_1",
        "px_left": 4790,
        "px_top": 350,
        "px_bottom": 8192,
        "px_right": 114600,
    },
    # nmx3662b
    {
        "name": "nmx3662b_1",
        "px_left": 8149,
        "px_top": 1200,
        "px_bottom": 6179,
        "px_right": 117607,
    },
    {
        "name": "nmx3662b_2",
        "px_left": 8126,
        "px_top": 1165,
        "px_bottom": 4910,
        "px_right": (117607 - 8149) + 8126,
    },  # Calculated
    # nmx3663b
    {
        "name": "nmx3663b_1",
        "px_left": 8118,
        "px_top": 1200,
        "px_bottom": 6051,
        "px_right": 118336,
    },
    {
        "name": "nmx3663b_2",
        "px_left": 8094,
        "px_top": 1046,
        "px_bottom": 5920,
        "px_right": (118336 - 8118) + 8094,
    },  # Calculated
    # nmx3664d
    {
        "name": "nmx3664d_1",
        "px_left": 5460,
        "px_top": 800,
        "px_bottom": 6360,
        "px_right": 115544,
    },
    {
        "name": "nmx3664d_2",
        "px_left": 5435,
        "px_top": 1338,
        "px_bottom": 5360,
        "px_right": (115544 - 5460) + 5435,
    },  # Calculated
    # nmx3664e
    {
        "name": "nmx3664e_1",
        "px_left": 4972,
        "px_top": 650,
        "px_bottom": 6749,
        "px_right": 115320,
    },
    {
        "name": "nmx3664e_2",
        "px_left": 4948,
        "px_top": 1733,
        "px_bottom": 5080,
        "px_right": (115320 - 4972) + 4948,
    },  # Calculated
    # nmx3665b (only one part)
    {
        "name": "nmx3665b_1",
        "px_left": 9430,
        "px_top": 1020,
        "px_bottom": 8192,
        "px_right": 118652,
    },
    # nmx3667a
    {
        "name": "nmx3667a_1",
        "px_left": 6619,
        "px_top": 1000,
        "px_bottom": 7128,
        "px_right": 114900,
    },
    {
        "name": "nmx3667a_2",
        "px_left": 6595,
        "px_top": 2111,
        "px_bottom": 5000,
        "px_right": (114900 - 6619) + 6595,
    },  # Calculated
    # nmx3667b
    {
        "name": "nmx3667b_1",
        "px_left": 6574,
        "px_top": 3250,
        "px_bottom": 6611,
        "px_right": 115044,
    },
    {
        "name": "nmx3667b_2",
        "px_left": 6555,
        "px_top": 1593,
        "px_bottom": 5100,
        "px_right": (115044 - 6574) + 6555,
    },  # Calculated
    # nmx3668c
    {
        "name": "nmx3668c_1",
        "px_left": 5625,
        "px_top": 700,
        "px_bottom": 6790,
        "px_right": 115500,
    },
    {
        "name": "nmx3668c_2",
        "px_left": 5602,
        "px_top": 1773,
        "px_bottom": 5670,
        "px_right": (115500 - 5625) + 5602,
    },  # Calculated
    # nmx3669c
    {
        "name": "nmx3669c_1",
        "px_left": 5709,
        "px_top": 1670,
        "px_bottom": 6604,
        "px_right": 114100,
    },
    {
        "name": "nmx3669c_2",
        "px_left": 5684,
        "px_top": 1591,
        "px_bottom": 5992,
        "px_right": (114100 - 5709) + 5684,
    },  # Calculated
    # nmx3670b
    {
        "name": "nmx3670b_1",
        "px_left": 7240,
        "px_top": 1500,
        "px_bottom": 7047,
        "px_right": 114130,
    },
    {
        "name": "nmx3670b_2",
        "px_left": 7216,
        "px_top": 2034,
        "px_bottom": 4400,
        "px_right": (114130 - 7240) + 7216,
    },  # Calculated
    # nmx3671b
    {
        "name": "nmx3671b_1",
        "px_left": 7098,
        "px_top": 1400,
        "px_bottom": 6930,
        "px_right": 115425,
    },
    {
        "name": "nmx3671b_2",
        "px_left": 7075,
        "px_top": 1923,
        "px_bottom": 5600,
        "px_right": (115425 - 7098) + 7075,
    },  # Calculated
    # nmx3673c
    {
        "name": "nmx3673c_1",
        "px_left": 6302,
        "px_top": 530,
        "px_bottom": 7161,
        "px_right": 114360,
    },
    {
        "name": "nmx3673c_2",
        "px_left": 6276,
        "px_top": 2145,
        "px_bottom": 5000,
        "px_right": (114360 - 6302) + 6276,
    },  # Calculated
    # nmx3674c
    {
        "name": "nmx3674c_1",
        "px_left": 5486,
        "px_top": 1230,
        "px_bottom": 6564,
        "px_right": 115200,
    },
    {
        "name": "nmx3674c_2",
        "px_left": 5461,
        "px_top": 1555,
        "px_bottom": 6170,
        "px_right": (115200 - 5486) + 5461,
    },  # Calculated
    # nmx3676c
    {
        "name": "nmx3676c_1",
        "px_left": 4700,
        "px_top": 1600,
        "px_bottom": 7060,
        "px_right": 114800,
    },
    {
        "name": "nmx3676c_2",
        "px_left": 4680,
        "px_top": 2040,
        "px_bottom": 6350,
        "px_right": (114800 - 4700) + 4680,
    },  # Calculated
    # nmx3677d
    {
        "name": "nmx3677d_1",
        "px_left": 5086,
        "px_top": 950,
        "px_bottom": 6891,
        "px_right": 113940,
    },
    {
        "name": "nmx3677d_2",
        "px_left": 5064,
        "px_top": 1882,
        "px_bottom": 6000,
        "px_right": (113940 - 5086) + 5064,
    },  # Calculated
    # nmx3680b
    {
        "name": "nmx3680b_1",
        "px_left": 4344,
        "px_top": 1750,
        "px_bottom": 6624,
        "px_right": 113860,
    },
    {
        "name": "nmx3680b_2",
        "px_left": 4302,
        "px_top": 1610,
        "px_bottom": 6420,
        "px_right": (113860 - 4344) + 4302,
    },  # Calculated
    # nmx3681c
    {
        "name": "nmx3681c_1",
        "px_left": 3662,
        "px_top": 1440,
        "px_bottom": 6943,
        "px_right": 112692,
    },
    {
        "name": "nmx3681c_2",
        "px_left": 3636,
        "px_top": 1930,
        "px_bottom": 6500,
        "px_right": (112692 - 3662) + 3636,
    },  # Calculated
    # nmx3682c
    {
        "name": "nmx3682c_1",
        "px_left": 2472,
        "px_top": 2290,
        "px_bottom": 6360,
        "px_right": 111790,
    },
    {
        "name": "nmx3682c_2",
        "px_left": 2449,
        "px_top": 1350,
        "px_bottom": 6900,
        "px_right": (111790 - 2472) + 2449,
    },  # Calculated
    # nmx3684b
    {
        "name": "nmx3684b_1",
        "px_left": 5085,
        "px_top": 2468,
        "px_bottom": 6876,
        "px_right": 113742,
    },
    {
        "name": "nmx3684b_2",
        "px_left": 5062,
        "px_top": 1865,
        "px_bottom": 6200,
        "px_right": (113742 - 5085) + 5062,
    },  # Calculated
    # nmx3685c
    {
        "name": "nmx3685c_1",
        "px_left": 5294,
        "px_top": 1000,
        "px_bottom": 6839,
        "px_right": 112500,
    },
    {
        "name": "nmx3685c_2",
        "px_left": 5267,
        "px_top": 1824,
        "px_bottom": 5430,
        "px_right": (112500 - 5294) + 5267,
    },  # Calculated
    # nmx3686c
    {
        "name": "nmx3686c_1",
        "px_left": 5424,
        "px_top": 1000,
        "px_bottom": 6725,
        "px_right": 114500,
    },
    {
        "name": "nmx3686c_2",
        "px_left": 5400,
        "px_top": 1712,
        "px_bottom": 4512,
        "px_right": (114500 - 5424) + 5400,
    },  # Calculated
]
# Out:
#           name  px_left  px_top  px_bottom  px_right
# 0   nmx3642b_1    59023     888       6814    117782
# 1   nmx3642b_2    58998    1784       5950    117757
# 2   nmx3642c_1     8311    1200       6406     59020
# 3   nmx3642c_2     8286    1385       6027     58995
# 4   nmx3643b_1    10045    1430       6826    118645
# ..         ...      ...     ...        ...       ...
# 70  nmx3684b_2     5062    1865       6200    113719
# 71  nmx3685c_1     5294    1000       6839    112500
# 72  nmx3685c_2     5267    1824       5430    112473
# 73  nmx3686c_1     5424    1000       6725    114500
# 74  nmx3686c_2     5400    1712       4512    114476
#
# [75 rows x 5 columns]

# %%
# Convert the list of dictionaries to a DataFrame
# Each dictionary in the list becomes a row in the DataFrame
df = pd.DataFrame(slicing_data)
print(df)

# Save the DataFrame to a CSV file
# Create the output directory if it doesn't exist
notebook_dir = Path.cwd()
project_root = notebook_dir.parent
output_dir = project_root / "data" / "csv"
output_file = output_dir / "slicing_param.csv"
output_dir.mkdir(parents=True, exist_ok=True)
df.to_csv(output_file, index=False)
print(f"DataFrame saved to {output_file}")
# Out:
#           name  px_left  px_top  px_bottom  px_right
# 0   nmx3642b_1    59023     888       6814    117782
# 1   nmx3642b_2    58998    1784       5950    117757
# 2   nmx3642c_1     8311    1200       6406     59020
# 3   nmx3642c_2     8286    1385       6027     58995
# 4   nmx3643b_1    10045    1430       6826    118645
# ..         ...      ...     ...        ...       ...
# 70  nmx3684b_2     5062    1865       6200    113719
# 71  nmx3685c_1     5294    1000       6839    112500
# 72  nmx3685c_2     5267    1824       5430    112473
# 73  nmx3686c_1     5424    1000       6725    114500
# 74  nmx3686c_2     5400    1712       4512    114476
#
# [75 rows x 5 columns]
# DataFrame saved to /home/miguel/Documents/10_projects/Grainable-ice/data/csv/slicing_param.csv
